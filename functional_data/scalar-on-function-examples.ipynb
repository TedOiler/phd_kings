# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %%
x = np.arange(-3, 3, step=0.01)
y = x**5 + x**4 - 3*x**3 - x**2 - 0.5*x
plt.plot(x, y)
plt.ylim(-10,10)
# Out:
# (-10.0, 10.0)
